# %% [markdown]
# # Project: Wrangling and Analyzing Data on sales of medications for the First half of 2022 (1st january 2022 to 1st july 2022) at Vedic Lifecare Hospital

# %% [markdown]
# ## Data Gathering

# %% [markdown]
# In the cell below, I gathered all pieces of data for this project from the hospital's database and loaded them in the notebook.
#
# Note: the methods required to gather each data are clearly stated.

# %% [markdown]
# ![Screenshot_20211108-114546_Instagram.jpg](attachment:Screenshot_20211108-114546_Instagram.jpg)

# %% [markdown]
# Through clinical excellence, we provide patient-centered, ethical treatment with empathy. We ensure that our efforts reflect that we are truly your health partner.
#
#
# Vedic Lifecare hospital has a team of expert doctors, trained nurses, and caregivers, and the patient's total well-being is our first focus. You can put your trust in their professional hands to get you back to health.
#
#
# Our high-end infrastructure and facilities utilize all the features of modern-day equipments to bring you the best quality treatment.
#
#
# Doctors at Vedic collaborate across specialities in the hospital to provide comprehensive care tailored specifically to the needs of every patient. Because effective treatment largely depends on identifying the right problem, our specialist doctors work tirelessly to provide solutions and proper treatment to a wide range of complex health conditions.
#
#
# There is a comprehensive orthopaedic department covering all orthopaedic subspecialties. Advanced tertiary level poly-trauma management protocols...
#
#
# The Obstetrics & Gynaecology department of Vedic Lifecare offers the most advanced comprehensive care...
#
#
# Vedic Lifecare Hospital is already on the panel of the leading HMOs in Nigeria
#
#
# We will always be happy to assist you in finding an answer to any health query or concern you may have. This is what we enjoy doing.

# %% [markdown]
# ![EwupgQDVoAMXmAX.jpg](attachment:EwupgQDVoAMXmAX.jpg)

# %% [markdown]
# Contact Us
#
# Phone Number = +234 708 400 8982
#
# Address: Block No 105, Plot 6 Olabanji Olajide Street,
# Lekki Phase 1, Lagos, Nigeria.
#
# Email:- info@vediclifecare.com
#
#
# Book an Appointment
#
#
# Call us and let us know how we can help you.

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------

# %% [markdown]
# **Analysis by Pharm Ezeizu Vitalis Chiebuka**

# %% [markdown]
# --------------------------------------------------------------------------

# %% [markdown]
# **First start by importing the necessary libraries and packages needed for this operation**

# %%
#Importing pandas and numpy to analyze and store data in the dataframe

import pandas as pd

import numpy as np

# %%
#Importing for visualization

import matplotlib.pyplot as plt

import seaborn as sns

# %matplotlib inline

# %%
# Importing other packages

import time

import datetime

import sklearn

import os

import io

# %%
# Upgrade pandas to use dataframe.explode() function. 

# !pip install --upgrade pandas==0.25.0
# Out:
#   ERROR: Command errored out with exit status 1:
# ...
#   Using cached pandas-0.25.0.tar.gz (12.6 MB)
# ...
#   Running setup.py clean for pandas
# Failed to build pandas
# ...
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.2.4
#     Uninstalling pandas-1.2.4:
#       Successfully uninstalled pandas-1.2.4
#     Running setup.py install for pandas: started
#     Running setup.py install for pandas: still running...
#     Running setup.py install for pandas: still running...
#     Running setup.py install for pandas: finished with status 'error'
#   Rolling back uninstall of pandas
#   Moving to c:\users\pharmacy1\anaconda3\lib\site-packages\pandas-1.2.4.dist-info\
#    from C:\Users\pharmacy1\Anaconda3\Lib\site-packages\~andas-1.2.4.dist-info
#   Moving to c:\users\pharmacy1\anaconda3\lib\site-packages\pandas\
#    from C:\Users\pharmacy1\Anaconda3\Lib\site-packages\~andas
# ...

# %% [markdown]
# 1. Directly download the Sales items report from the hospital's database

# %%
# Gathering and downloading the datasets 

dp = pd.read_csv("C:\\Users\\pharmacy1\\Downloads\\Sale Items Report2022-07-01 at 23_14_38.csv")

# %% [markdown]
# ---------------------------------------------------------------------------

# %% [markdown]
# ## Assessing Data

# %% [markdown]
# In this section, I detected and documented the quality issues and tidiness issue. I use both visual assessment and programmatic assessement to assess the data.
#
# Note: paid attention to the following key points when accessing the data

# %%
# Displaying the first five records

dp.head(5)
# Out:
#    Unnamed: 0  Unnamed: 1              Unnamed: 2  \
# 0         NaN         NaN                     NaN
# 1         NaN         NaN                     NaN
# 2  sales_bill  sales_date          patient's_name
# 3    SB052573  01/01/2022  Master Eniola Onasanya
# 4    SB052573  01/01/2022  Master Eniola Onasanya
#
#                                    Unnamed: 3  \
# 0                                         NaN
# 1                                         NaN
# 2                                 medications
# 3                     EMZOR PARACETAMOL 500MG
# 4  OLICEF-CEFUROXIME AXETIL SUSPENSION 125 MG
#
#                                    Sale Items Report Unnamed: 5  \
# 0  Filtered on: Store Name equals Main Centre Pha...        NaN
# 1                           01-01-2022 to 01-07-2022        NaN
# 2                                              batch  sale_rate
# 3                                               074A         10
# ...

# %% [markdown]
# The sales report dataset contains the following paraemters:
#
#
# 1) Sales bill: the unique identifier for each patient at the hospital
#
#
# 2) Sales date: the exact date the medication was purchased from the hospital
#
#
# 3) Patient's name: the full name of the patient purchasing the medication
#
#
# 4) Medications: the therapeutic agent purchased from the pharmacy department
#
#
# 5) Batch: the unique number of the medication gotten from the pharmacy department
#
#
# 6) Sales rate: the unit price of the medication
#
#
# 7) Sales qty: the total number of medications purchased from the pharmacy department
#
#
# 8) Sales UOM: unique representation of the sale qty.
#
#
# 9) Net amt: the total amount of the medication purchased from the pharmacy department.

# %%
# Reassigning the column headers

header_row = 2

df.columns = df.iloc[header_row]

# %%
# Dropping the header rowin the dataset

df = df.drop(header_row)

# %%
# Resetting the index for the dataset

df = df.reset_index(drop = True)

# %%
# Accessing the first five records

dp.head(5)
# Out:
#    Unnamed: 0  Unnamed: 1              Unnamed: 2  \
# 0         NaN         NaN                     NaN
# 1         NaN         NaN                     NaN
# 2  sales_bill  sales_date          patient's_name
# 3    SB052573  01/01/2022  Master Eniola Onasanya
# 4    SB052573  01/01/2022  Master Eniola Onasanya
#
#                                    Unnamed: 3  \
# 0                                         NaN
# 1                                         NaN
# 2                                 medications
# 3                     EMZOR PARACETAMOL 500MG
# 4  OLICEF-CEFUROXIME AXETIL SUSPENSION 125 MG
#
#                                    Sale Items Report Unnamed: 5  \
# 0  Filtered on: Store Name equals Main Centre Pha...        NaN
# 1                           01-01-2022 to 01-07-2022        NaN
# 2                                              batch  sale_rate
# 3                                               074A         10
# ...

# %%
# Getting the last five records

dp.tail(5)
# Out:
#       Unnamed: 0  Unnamed: 1             Unnamed: 2  \
# 11680   SB058003  01/07/2022         Ms. SERAH INOK
# 11681   SB058003  01/07/2022         Ms. SERAH INOK
# 11682   SB058003  01/07/2022         Ms. SERAH INOK
# 11683   SB058004  01/07/2022  Mr. Opaleye A Adewale
# 11684        NaN         NaN                    NaN
#
#                                              Unnamed: 3 Sale Items Report  \
# 11680        COARTEM - ARTEMETHER/LUMEFANTRINE 80/480MG             KDM76
# 11681                                ERYTHROMYCIN 500MG             T1001
# 11682  DICLOMOL - DICLOFENAC 50MG - ACETAMINOPHEN 500MG        22A002TC01
# 11683                LEVAMISOLE HYDROCHLORIDE  TAB 40MG             EH069
# 11684                                               NaN               NaN
#
#       Unnamed: 5 Unnamed: 6    Unnamed: 7   Unnamed: 8
# 11680        500          6       Numbers         3000
# 11681        125         15       Numbers         1875
# ...

# %%
# Getting the concise summary of the dataset

dp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11685 entries, 0 to 11684
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         11682 non-null  object
#  1   Unnamed: 1         11682 non-null  object
#  2   Unnamed: 2         11682 non-null  object
#  3   Unnamed: 3         11682 non-null  object
#  4   Sale Items Report  11684 non-null  object
#  5   Unnamed: 5         11682 non-null  object
#  6   Unnamed: 6         11682 non-null  object
#  7   Unnamed: 7         11683 non-null  object
#  8   Unnamed: 8         11683 non-null  object
# dtypes: object(9)
# memory usage: 821.7+ KB

# %%
# Checking the size of the dataset

dp.shape
# Out:
# (11685, 9)

# %% [markdown]
# The dataset contains 9 columns and 11685 rows

# %%
# Checking the datatype of the dataset

dp.dtypes
# Out:
# Unnamed: 0           object
# Unnamed: 1           object
# Unnamed: 2           object
# Unnamed: 3           object
# Sale Items Report    object
# Unnamed: 5           object
# Unnamed: 6           object
# Unnamed: 7           object
# Unnamed: 8           object
# dtype: object

# %%
# Getting the descriptive statistics of the dataset

dp.describe()
# Out:
#        Unnamed: 0  Unnamed: 1 Unnamed: 2               Unnamed: 3  \
# count       11682       11682      11682                    11682
# unique       4872         183       2106                      665
# top      SB055565  18/04/2022    WALK-IN  EMZOR PARACETAMOL 500MG
# freq           29         159        242                      394
#
#        Sale Items Report Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8
# count              11684      11682      11682      11683      11683
# unique              1140        297         95          3        595
# top                 074A        100          1    Numbers       1000
# freq                 390       1039       4521      11681        906

# %%
# Getting random 5 sample of the dataset

dp.sample(5)
# Out:
#      Unnamed: 0  Unnamed: 1                Unnamed: 2  \
# 1460   SB053246  29/01/2022       Miss Blessing Titus
# 4861   SB054923  30/03/2022  Mr. David Samuel Akinola
# 3201   SB054112  04/03/2022         Dr. Ashraff Pasha
# 5592   SB055236  09/04/2022           Mr. Mitul Patel
# 514    SB052787  12/01/2022        Mrs. Victoria Udeh
#
#                                      Unnamed: 3 Sale Items Report Unnamed: 5  \
# 1460                      MANITOL 10% INF 500ML            109005       1000
# 4861        FINE TEST BLOOD GLUCOSE TEST STRIPS         A21F079C1        300
# 3201                     GLUCOMETER STRIPS (LP)          26031332        300
# 5592                             CIPROTAB 500MG           C011016        300
# 514   SWIDAR-SULFADOXINE+PYRIMETHAMINE-500/25MG           L220021        200
#
#      Unnamed: 6 Unnamed: 7 Unnamed: 8
# 1460          2    Numbers       2000
# 4861          3    Numbers        900
# 3201         50    Numbers      15000
# ...

# %%
# Checking for missing values

dp.columns[dp.isnull().any()].tolist()
# Out:
# ['Unnamed: 0',
#  'Unnamed: 1',
#  'Unnamed: 2',
#  'Unnamed: 3',
#  'Sale Items Report',
#  'Unnamed: 5',
#  'Unnamed: 6',
#  'Unnamed: 7',
#  'Unnamed: 8']

# %%
# Checking row for missing value

dp.isnull()
# Out:
#        Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  Sale Items Report  \
# 0            True        True        True        True              False
# 1            True        True        True        True              False
# 2           False       False       False       False              False
# 3           False       False       False       False              False
# 4           False       False       False       False              False
# ...           ...         ...         ...         ...                ...
# 11680       False       False       False       False              False
# 11681       False       False       False       False              False
# 11682       False       False       False       False              False
# 11683       False       False       False       False              False
# 11684        True        True        True        True               True
#
#        Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8
# ...

# %%
# Checking for duplicated values

dp.duplicated().any()
# Out:
# False

# %% [markdown]
# # Important Information

# %% [markdown]
# I have gone through the entire dataset to check for the number of columns, number of rows, presence of duplicated value, presence of missing values, the statistical figure of the dataset and the number of Unique characters.
#
#
# The dataset have been gathered and were properly assessed. With the assessment, I looked for quality and tidiness issues.
#
# Quality : Low-quality data is commonly referred to as dirty data. Dirty data has issues with its content. The Data Quality Dimensions are Completeness, Validity, Accuracy, and Consistency.
#
# Tidiness : Untidy data is commonly referred to as “messy” data. Messy data has issues with its structure. Tidy data is where:
#
# Each variable forms a column.
#
# Each observation forms a row.
#
# Each type of observational unit forms a table.
#
# After visually assessing the data in DataFrames and in excel spreadsheets, and programmatically assessing the three DataFrames individually, I found 8 quality issues and all were documented in my jupyter notebook.

# %% [markdown]
# # Quality issues

# %% [markdown]
# 1) Null/NaN values
#
#
# 2) Missing value
#
#
# 3) Columns which holds no data as: patient's name and sale uom
#
#
# 4) Column's header name
#
#
# 5) First row of the dataset
#
#
# 6) Ordering the index number
#
#
# 7) Sales date datatype to be in datetime data type
#
#
# 8) Wrong datatype for sale rate, sale quantity and net amt

# %% [markdown]
# # Cleaning Data

# %% [markdown]
# In this section, we cleaned all of the issues documented while assessing.
#
# Note: A copy of the original data was made before cleaning. Cleaning includes merging individual pieces of data according to the rules of tidy data.
#
# The result is of high-quality and tidy master pandas DataFrame (or DataFrames, if appropriate).

# %%
# Making copies of original pieces of data

# Making a copy for sales items report

bt_cln = dp.copy()
# Out:
#   copying pandas\io\sas\__init__.py -> build\lib.win-amd64-3.8\pandas\io\sas
#   creating build\lib.win-amd64-3.8\pandas\plotting\_matplotlib
#   copying pandas\plotting\_matplotlib\boxplot.py -> build\lib.win-amd64-3.8\pandas\plotting\_matplotlib
#   copying pandas\plotting\_matplotlib\compat.py -> build\lib.win-amd64-3.8\pandas\plotting\_matplotlib
#   copying pandas\plotting\_matplotlib\converter.py -> build\lib.win-amd64-3.8\pandas\plotting\_matplotlib
#   copying pandas\plotting\_matplotlib\core.py -> build\lib.win-amd64-3.8\pandas\plotting\_matplotlib
#   copying pandas\plotting\_matplotlib\hist.py -> build\lib.win-amd64-3.8\pandas\plotting\_matplotlib
#   copying pandas\plotting\_matplotlib\misc.py -> build\lib.win-amd64-3.8\pandas\plotting\_matplotlib
#   copying pandas\plotting\_matplotlib\style.py -> build\lib.win-amd64-3.8\pandas\plotting\_matplotlib
#   copying pandas\plotting\_matplotlib\timeseries.py -> build\lib.win-amd64-3.8\pandas\plotting\_matplotlib
# ...

# %% [markdown]
# ## Issue #1:

# %% [markdown]
# ### Define:

# %% [markdown]
# Unifying the null/NaN value

# %% [markdown]
# ### Code

# %%
# Replacing the null value to be Nan

bt_cln.replace('None', np.nan, inplace = True)
# Out:
#     creating build\lib.win-amd64-3.8
#     creating build\lib.win-amd64-3.8\pandas
#     copying pandas\conftest.py -> build\lib.win-amd64-3.8\pandas
#     copying pandas\testing.py -> build\lib.win-amd64-3.8\pandas
#     copying pandas\_typing.py -> build\lib.win-amd64-3.8\pandas
#     copying pandas\_version.py -> build\lib.win-amd64-3.8\pandas
#     copying pandas\__init__.py -> build\lib.win-amd64-3.8\pandas
#     creating build\lib.win-amd64-3.8\pandas\api
#     copying pandas\api\__init__.py -> build\lib.win-amd64-3.8\pandas\api
#     creating build\lib.win-amd64-3.8\pandas\arrays
#     copying pandas\arrays\__init__.py -> build\lib.win-amd64-3.8\pandas\arrays
#     creating build\lib.win-amd64-3.8\pandas\compat
#     copying pandas\compat\chainmap.py -> build\lib.win-amd64-3.8\pandas\compat
#     copying pandas\compat\pickle_compat.py -> build\lib.win-amd64-3.8\pandas\compat
#     copying pandas\compat\_optional.py -> build\lib.win-amd64-3.8\pandas\compat
# ...

# %% [markdown]
# ### Test

# %%
bt_cln.info()
# Out:
#     copying pandas\core\tools\timedeltas.py -> build\lib.win-amd64-3.8\pandas\core\tools
#     copying pandas\core\tools\__init__.py -> build\lib.win-amd64-3.8\pandas\core\tools
#     creating build\lib.win-amd64-3.8\pandas\core\util
#     copying pandas\core\util\hashing.py -> build\lib.win-amd64-3.8\pandas\core\util
#     copying pandas\core\util\__init__.py -> build\lib.win-amd64-3.8\pandas\core\util
#     creating build\lib.win-amd64-3.8\pandas\io\clipboard
#     copying pandas\io\clipboard\clipboards.py -> build\lib.win-amd64-3.8\pandas\io\clipboard
#     copying pandas\io\clipboard\exceptions.py -> build\lib.win-amd64-3.8\pandas\io\clipboard
#     copying pandas\io\clipboard\windows.py -> build\lib.win-amd64-3.8\pandas\io\clipboard
#     copying pandas\io\clipboard\__init__.py -> build\lib.win-amd64-3.8\pandas\io\clipboard
#     creating build\lib.win-amd64-3.8\pandas\io\excel
#     copying pandas\io\excel\_base.py -> build\lib.win-amd64-3.8\pandas\io\excel
# ...

# %% [markdown]
# ## Issue #2:

# %% [markdown]
# ### Define

# %% [markdown]
# Dropping all missing values in the dataset

# %% [markdown]
# ### Code

# %%
# Dropping all missing values in the dataset

bt_cln.dropna(axis = 0, how = 'any', inplace = True)

# %% [markdown]
# ### Test

# %%
bt_cln.head(5)
# Out:
#    Unnamed: 0  Unnamed: 1              Unnamed: 2  \
# 2  sales_bill  sales_date          patient's_name
# 3    SB052573  01/01/2022  Master Eniola Onasanya
# 4    SB052573  01/01/2022  Master Eniola Onasanya
# 5    SB052573  01/01/2022  Master Eniola Onasanya
# 6    SB052574  01/01/2022         Miss Suad Bello
#
#                                    Unnamed: 3 Sale Items Report Unnamed: 5  \
# 2                                 medications             batch  sale_rate
# 3                     EMZOR PARACETAMOL 500MG              074A         10
# 4  OLICEF-CEFUROXIME AXETIL SUSPENSION 125 MG           U0E2005       4000
# 5                       COARTEM DISPERSIBLE 6             KV293        200
# 6                       COARTEM DISPERSIBLE 6             KV293        200
#
#       Unnamed: 6 Unnamed: 7 Unnamed: 8
# 2  sale_quantity   sale_uom    net_amt
# 3             12    Numbers        120
# 4              1    Numbers       4000
# 5             12    Numbers       2400
# ...

# %% [markdown]
# ## Issue #3:

# %% [markdown]
# ### Define

# %% [markdown]
# Remove columns which holds no data or low amount of data like: patients's name and sale uom

# %% [markdown]
# ### Code

# %%
# Dropping unwanted columns

bt_cln.drop(columns=["patient_name", "sale_uom",], inplace = True)

# %% [markdown]
# ### Test

# %%
bt_cln.head(5)
# Out:
#    sales_bill  sales_date                                 medications  \
# 2  sales_bill  sales_date                                 medications
# 3    SB052573  01/01/2022                     EMZOR PARACETAMOL 500MG
# 4    SB052573  01/01/2022  OLICEF-CEFUROXIME AXETIL SUSPENSION 125 MG
# 5    SB052573  01/01/2022                       COARTEM DISPERSIBLE 6
# 6    SB052574  01/01/2022                       COARTEM DISPERSIBLE 6
#
#      batch  sale_rate  sale_quantity  net_amt
# 2    batch  sale_rate  sale_quantity  net_amt
# 3     074A         10             12      120
# 4  U0E2005       4000              1     4000
# 5    KV293        200             12     2400
# 6    KV293        200             12     2400

# %% [markdown]
# ## Issue #4:

# %% [markdown]
# ### Define

# %% [markdown]
# Renaming the total column header for easy readability

# %% [markdown]
# ### Code

# %%
bt_cln.rename(columns={'Unnamed: 0':'sales_bill', 'Unnamed: 1':'sales_date', 'Unnamed: 2':'patient_name', 'Unnamed: 3':'medications', 'Sale Items Report':'batch', 'Unnamed: 5':'sale_rate', 'Unnamed: 6':'sale_quantity', 'Unnamed: 7':'sale_uom','Unnamed: 8':'net_amt'}, inplace = True)

# %% [markdown]
# ### Test

# %%
bt_cln.head(2)
# Out:
#    sales_bill  sales_date              medications  batch  sale_rate  \
# 2  sales_bill  sales_date              medications  batch  sale_rate
# 3    SB052573  01/01/2022  EMZOR PARACETAMOL 500MG   074A         10
#
#    sale_quantity  net_amt
# 2  sale_quantity  net_amt
# 3             12      120

# %% [markdown]
# ## Issue #5:

# %% [markdown]
# ### Define

# %% [markdown]
# Dropping the first row in the dataset

# %% [markdown]
# ### Code

# %%
bt_cln = bt_cln.drop(labels=2, axis=0)

# %% [markdown]
# ### Test

# %%
bt_cln.head()
# Out:
#   sales_bill  sales_date                                 medications  \
# 3   SB052573  01/01/2022                     EMZOR PARACETAMOL 500MG
# 4   SB052573  01/01/2022  OLICEF-CEFUROXIME AXETIL SUSPENSION 125 MG
# 5   SB052573  01/01/2022                       COARTEM DISPERSIBLE 6
# 6   SB052574  01/01/2022                       COARTEM DISPERSIBLE 6
# 7   SB052575  01/01/2022               PARACETAMOL INFUSION 1G/100ML
#
#       batch sale_rate sale_quantity net_amt
# 3      074A        10            12     120
# 4   U0E2005      4000             1    4000
# 5     KV293       200            12    2400
# 6     KV293       200            12    2400
# 7  A21C015N      2000             1    2000

# %% [markdown]
# ## Issue #6:

# %% [markdown]
# ### Define

# %% [markdown]
# Reseting/reordering the index number

# %% [markdown]
# ### Code

# %%
bt_cln.reset_index(drop=True, inplace=True)

# %% [markdown]
# ### Test

# %%
bt_cln.head(5)
# Out:
#   sales_bill  sales_date                                 medications  \
# 0   SB052573  01/01/2022                     EMZOR PARACETAMOL 500MG
# 1   SB052573  01/01/2022  OLICEF-CEFUROXIME AXETIL SUSPENSION 125 MG
# 2   SB052573  01/01/2022                       COARTEM DISPERSIBLE 6
# 3   SB052574  01/01/2022                       COARTEM DISPERSIBLE 6
# 4   SB052575  01/01/2022               PARACETAMOL INFUSION 1G/100ML
#
#       batch sale_rate sale_quantity net_amt
# 0      074A        10            12     120
# 1   U0E2005      4000             1    4000
# 2     KV293       200            12    2400
# 3     KV293       200            12    2400
# 4  A21C015N      2000             1    2000

# %% [markdown]
# ## Issue #7:

# %% [markdown]
# ### Define

# %% [markdown]
# Converting the sales date to be datetime

# %% [markdown]
# ### Code

# %%
bt_cln.sales_date = pd.to_datetime(bt_cln['sales_date'])

# %% [markdown]
# ### Test

# %%
bt_cln.dtypes
# Out:
# sales_bill               object
# sales_date       datetime64[ns]
# medications              object
# batch                    object
# sale_rate                object
# sale_quantity            object
# net_amt                  object
# dtype: object

# %% [markdown]
# ## Issue #8:

# %% [markdown]
# ### Define

# %% [markdown]
# Converting sale rate, sale quantity and net amt to their right datatype

# %% [markdown]
# ### Code

# %%
# Converting sale rate, sale qty and net amt to its right dataframe

bt_cln['sale_rate'].astype(str).astype(float)
# Out:
# 0          10.0
# 1        4000.0
# 2         200.0
# 3         200.0
# 4        2000.0
#           ...
# 11676     438.0
# 11677     500.0
# 11678     125.0
# 11679      25.0
# 11680     300.0
# Name: sale_rate, Length: 11681, dtype: float64

# %%
bt_cln['sale_rate'].astype(float).astype(int)
# Out:
# 0          10
# 1        4000
# 2         200
# 3         200
# 4        2000
#          ...
# 11676     438
# 11677     500
# 11678     125
# 11679      25
# 11680     300
# Name: sale_rate, Length: 11681, dtype: int32

# %%
bt_cln['net_amt'].astype(str).astype(float)
# Out:
# 0         120.0
# 1        4000.0
# 2        2400.0
# 3        2400.0
# 4        2000.0
#           ...
# 11676     438.0
# 11677    3000.0
# 11678    1875.0
# 11679     250.0
# 11680    3600.0
# Name: net_amt, Length: 11681, dtype: float64

# %%
bt_cln['net_amt'].astype(float).astype(int)
# Out:
# 0         120
# 1        4000
# 2        2400
# 3        2400
# 4        2000
#          ...
# 11676     438
# 11677    3000
# 11678    1875
# 11679     250
# 11680    3600
# Name: net_amt, Length: 11681, dtype: int32

# %%
bt_cln['sale_quantity'].astype(str).astype(int)
# Out:
# 0        12
# 1         1
# 2        12
# 3        12
# 4         1
#          ..
# 11676     1
# 11677     6
# 11678    15
# 11679    10
# 11680    12
# Name: sale_quantity, Length: 11681, dtype: int32

# %%
bt_cln['sale_quantity'].astype(float).astype(int)
# Out:
# 0        12
# 1         1
# 2        12
# 3        12
# 4         1
#          ..
# 11676     1
# 11677     6
# 11678    15
# 11679    10
# 11680    12
# Name: sale_quantity, Length: 11681, dtype: int32

# %% [markdown]
# ### Test

# %%
bt_cln.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11681 entries, 0 to 11680
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   sales_bill     11681 non-null  object
#  1   sales_date     11681 non-null  datetime64[ns]
#  2   medications    11681 non-null  object
#  3   batch          11681 non-null  object
#  4   sale_rate      11681 non-null  object
#  5   sale_quantity  11681 non-null  object
#  6   net_amt        11681 non-null  object
# dtypes: datetime64[ns](1), object(6)
# memory usage: 638.9+ KB

# %% [markdown]
# ## Storing Data

# %% [markdown]
# Save gathered, assessed, and cleaned master dataset to a CSV file named "sales_item.csv".

# %%
bt_cln.to_csv('sales_item.csv', encoding = 'utf-8', index = False)

# %%
# We save our data in a pickle format not to lose pandas types definitions in a text csv file.

bt_cln.to_pickle("./sales_item.csv.pkl")

# %% [markdown]
# ## Analyzing and Visualizing Data

# %% [markdown]
# As a result of data wrangling, the clean dataset is now ready for analyzing

# %%
# Reading the clean data

med = pd.read_csv('sales_item.csv')

# %%
# Getting the first five records

med.head(5)
# Out:
#   sales_bill  sales_date                                 medications  \
# 0   SB052573  2022-01-01                     EMZOR PARACETAMOL 500MG
# 1   SB052573  2022-01-01  OLICEF-CEFUROXIME AXETIL SUSPENSION 125 MG
# 2   SB052573  2022-01-01                       COARTEM DISPERSIBLE 6
# 3   SB052574  2022-01-01                       COARTEM DISPERSIBLE 6
# 4   SB052575  2022-01-01               PARACETAMOL INFUSION 1G/100ML
#
#       batch  sale_rate  sale_quantity  net_amt
# 0      074A       10.0             12    120.0
# 1   U0E2005     4000.0              1   4000.0
# 2     KV293      200.0             12   2400.0
# 3     KV293      200.0             12   2400.0
# 4  A21C015N     2000.0              1   2000.0

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# I've trimmed and cleaned my data, now ready to move on to exploration.
#
#
# I will Compute statistics and present my visualizations with the goal of addressing the questions posed in the Insights section.
#
#
# I'm going to compute the relevant statistics throughout the analysis when an inference is made about the data.

# %% [markdown]
# ## Insights:

# %% [markdown]
# 1) Most common Medications sold at the hospital?
#
#
# 2) Is there any significant relationship between medications sold at the hospital and their sales date?
#
#
#
# 3) Time Series Forecasting sales of medications for the next 2nd half (1st July 2022 to 1st January 2023) of the year

# %% [markdown]
# ### Import Neccessary Packages and Libraries

# %%
from math import sqrt

# %%
import plotly.offline as py

py.init_notebook_mode(connected=True)

import plotly.graph_objs as go

import plotly.tools as tls

from plotly.subplots import make_subplots

import plotly.figure_factory as ff
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
from sklearn.model_selection import StratifiedShuffleSplit, KFold, GridSearchCV, RandomizedSearchCV

from sklearn.base import BaseEstimator, TransformerMixin

from sklearn.pipeline import Pipeline

from sklearn.metrics import mean_squared_error, mean_absolute_error,make_scorer,r2_score

from sklearn.inspection import plot_partial_dependence

from statsmodels.stats.outliers_influence import variance_inflation_factor

import statsmodels.api  as sm

from scipy import stats

from sklearn.model_selection import train_test_split,cross_val_score

# %%
from sklearn.linear_model import Lasso, Ridge, SGDRegressor,LinearRegression,RidgeCV

from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor

from sklearn.preprocessing import LabelEncoder,OneHotEncoder,StandardScaler,RobustScaler

from sklearn.svm import SVR

from sklearn.pipeline import Pipeline

from xgboost import XGBRegressor

from sklearn.neighbors import KNeighborsRegressor

from sklearn.ensemble import GradientBoostingRegressor

from sklearn.tree import ExtraTreeRegressor,DecisionTreeRegressor

from sklearn.neural_network import MLPRegressor

import xgboost as xgb

import lightgbm as lgb

import plotly.figure_factory as ff

# %%
from statsmodels.graphics.gofplots import qqplot

from IPython.core.interactiveshell import InteractiveShell

# %%
import chart_studio
chart_studio.tools.set_credentials_file(username='masrinez', api_key='HLaJfZNuHUTaGeLe11NY')

# %%
# First five records

med.head(5)
# Out:
#   sales_bill  sales_date                                 medications  \
# 0   SB052573  2022-01-01                     EMZOR PARACETAMOL 500MG
# 1   SB052573  2022-01-01  OLICEF-CEFUROXIME AXETIL SUSPENSION 125 MG
# 2   SB052573  2022-01-01                       COARTEM DISPERSIBLE 6
# 3   SB052574  2022-01-01                       COARTEM DISPERSIBLE 6
# 4   SB052575  2022-01-01               PARACETAMOL INFUSION 1G/100ML
#
#       batch  sale_rate  sale_quantity  net_amt
# 0      074A       10.0             12    120.0
# 1   U0E2005     4000.0              1   4000.0
# 2     KV293      200.0             12   2400.0
# 3     KV293      200.0             12   2400.0
# 4  A21C015N     2000.0              1   2000.0

# %%
# Last 5 records

med.tail(5)
# Out:
#       sales_bill  sales_date  \
# 11676   SB058003  2022-01-07
# 11677   SB058003  2022-01-07
# 11678   SB058003  2022-01-07
# 11679   SB058003  2022-01-07
# 11680   SB058004  2022-01-07
#
#                                             medications       batch  \
# 11676                                DICLOFENAC GEL 30G      D08174
# 11677        COARTEM - ARTEMETHER/LUMEFANTRINE 80/480MG       KDM76
# 11678                                ERYTHROMYCIN 500MG       T1001
# 11679  DICLOMOL - DICLOFENAC 50MG - ACETAMINOPHEN 500MG  22A002TC01
# 11680                LEVAMISOLE HYDROCHLORIDE  TAB 40MG       EH069
#
#        sale_rate  sale_quantity  net_amt
# 11676      438.0              1    438.0
# 11677      500.0              6   3000.0
# 11678      125.0             15   1875.0
# 11679       25.0             10    250.0
# 11680      300.0             12   3600.0

# %% [markdown]
# ### Most common medication sold at the Hospital

# %%
# Unique value in the dataset

for column in med.columns.values:
    
    print(f" Unique values of {column} : {med[column].nunique()}")
# Out:
#  Unique values of sales_bill : 4871
#  Unique values of sales_date : 182
#  Unique values of medications : 664
#  Unique values of batch : 1137
#  Unique values of sale_rate : 296
#  Unique values of sale_quantity : 94
#  Unique values of net_amt : 593

# %%
# Top 20 medications sold at the hospital

top_meds = med.medications.value_counts().nlargest(20)

top_meds
# Out:
# EMZOR PARACETAMOL 500MG                             394
# PARACETAMOL INFUSION 1G/100ML                       284
# NORMAL SALINE 0.9% 500ML                            244
# DISPOSABLE FACE MASK (LP)                           200
# DICLOFENAC INJ 75MG/3ML                             179
# OMEPRAZOLE 20MG CAPS                                164
# PANTOPRAZOLE TABLET 40MG                            162
# LORATADINE 10MG TAB                                 138
# LONART ARTEMETHER 80MG + LUMEFANTRINE 480MG TAB     133
# CEFTRIAXONE 1G INJECTION                            131
# DICLOMOL - DICLOFENAC 50MG - ACETAMINOPHEN 500MG    129
# XYZAL - LEVOCETRIZEN TAB                            127
# SODIUM LACTATE INFUSION 500ML                       127
# COARTEM - ARTEMETHER/LUMEFANTRINE 80/480MG          123
# ABSORBED TETANUS VACCINE 0.5 ML (SII)               119
# DEXTROSE 5% + SALINE 0.9%                           116
# STERILE WATER FOR INJECTION                         115
# ...

# %%
# Bar chart showing the top 20 commonly sold medications at the hospital

top_meds.plot(kind='barh')

plt.xticks(rotation = 100)

plt.show()

# %%
# Distribution of medications in relation to total sales 

F = med.medications.value_counts().sort_values(ascending=False).nlargest(20)

trace1 = go.Bar (x=F.index, y=F.values, marker=dict(color = '#009688'))
                                                      
F = med.net_amt.value_counts().sort_values(ascending=False).nlargest(20)

trace2 = go.Bar (x=F.index, y=F.values, marker=dict( color ='#689F38' ))
 
fig = make_subplots (rows=1, cols=2, subplot_titles=('Medications','Total sales'))                                                        
 
fig.add_trace(trace1, 1,1) 

fig.add_trace(trace2, 1,2)  

fig['layout'].update(yaxis = dict(title = 'Values'), height=500, width=900, showlegend=False)

py.iplot(fig)
# Out:
#         <iframe
#             width="900px"
#             height="500px"
#             src="https://plotly.com/~masrinez/11.embed"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
# Distribution of the highest 20 Medications

F = med['medications'].value_counts().sort_values().nlargest(20)

label = F.index

size = F.values

colors = ['skyblue', '#FEBFB3', '#96D38C', '#D0F9B1', 'gold', 'orange', 'lightgrey', 
          'lightblue','lightgreen','aqua','yellow','#D4E157','#D1C4E9','#1A237E','#64B5F6','#009688',
          '#1DE9B6','#66BB6A','#689F38','#FFB300']

# %%
trace =go.Pie(labels=label, values=size, marker=dict(colors=colors), hole=.1)

data_trace = [trace]

layout = go.Layout(title='Distribution of Medications')

fig = go.Figure(data= data_trace, layout = layout)

py.iplot(fig)
# Out:
#         <iframe
#             width="100%"
#             height="525px"
#             src="https://plotly.com/~masrinez/3.embed"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# From our analysis,
#
# 1) I noticed Emzor paracetamol is the most widely sold medication for the first half of the year
#
#
# 2) There was a high sales of analgesics in the first half of the year
#
#
# 3) In comparing the anti malaria with the most sales volume, Lonart 80/480mg by greenlife achieved more purchasing rate than coartem 80/480 and amatem softgel 80/480 at the hospital
#
#
# 4) The high sales of anti histamines may be due to the rainy weather in lagos nigeria in the first half of the year leaving a lot of patients with flu/allergic reactions
#
#
# 5) The high sales of Proton pump inhibitors (PPIs) are medicines that work by reducing the amount of stomach acid made by glands in the lining of your stomach may be due to the inflation rate currently happening in nigeria leaving individuals to cut down on their diet leading to poor eating habits
#
#
# 6) The high sales of disposable masks is an indicator that nigeria is adhering with the covid-19 regulations so as to minimize the spread of the illness and protect themselves.
#
#
# 7) The most widely sold anti biotics is ceftriaxone 1G. The strict usage of antibiotics at the hospital is an indication that antibiotics stewardship is praticed so as to reduce antibiotics abuse that can lead to treatment failure.
#
#
# 8) Any Pharmaceutical with any of the medications above stand a good chance of acheiving a high sale rate at the hospital.

# %% [markdown]
# ### Is there any significant relationship between medications sold at the hospital and their sales date ?

# %%
#Let's start by checking the medications for number of unique value


med['medications'].nunique()
# Out:
# 664

# %%
# Using a bar chart to analyze the variable 'medications' using the first 10 records

med['medications'].value_counts().head(10).sort_values().plot(kind = 'bar', figsize=(25,15))
# Out:
# <AxesSubplot:>

# %%
# Using a bar chart to analyze the variable 'medication' using the last 10 records

med['medications'].value_counts().tail(10).sort_values().plot(kind = 'barh', figsize=(25,15))
# Out:
# <AxesSubplot:>

# %%
# Sorting through the medication variable

df1 = med.groupby('medications')['sales_date'].value_counts().sort_values( ascending = False)

df1
# Out:
# medications                            sales_date
# EMZOR PARACETAMOL 500MG                2022-06-25    10
# PANTOPRAZOLE TABLET 40MG               2022-04-18     9
# DISPOSABLE FACE MASK (LP)              2022-04-30     8
# EMZOR PARACETAMOL 500MG                2022-07-05     8
#                                        2022-06-27     8
#                                                      ..
#                                        2022-02-26     1
#                                        2022-02-24     1
#                                        2022-02-19     1
#                                        2022-02-18     1
# ZYNCET - CETRIZINE SYRUP 5MG/5ML 60ML  2022-12-04     1
# Name: sales_date, Length: 8582, dtype: int64

# %%
# Creating a chart to show correlation between sales date and counts

med['sales_date'].value_counts().head(50).plot(figsize = (18,10))

plt.xlabel('Sales date')

plt.ylabel('Counts')

plt.title('Sales date of medications')
# Out:
# Text(0.5, 1.0, 'Sales date of medications')

# %%
# Using a line graph to correlate between counts and sales date

df1.plot(kind = 'line',  figsize = (18,10))

plt.title('Sales date of medications')

plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
#Relationship between Sales date and medications

med.plot(kind = 'scatter', x = 'medications', y ='sales_date',figsize = (18,10))

plt.title('Relationship Between Sales date and medications')
# Out:
# Text(0.5, 1.0, 'Relationship Between Sales date and medications')

# %%
# Comparing medications with the sales dates

df1 = med.groupby('medications')['sales_date'].value_counts().head(30).sort_values(ascending = False)

df1.plot(kind = 'barh', stacked = True, figsize = (18,10))

plt.title('Medications being sold')

plt.legend(['Present','Absent'])

# %% [markdown]
# From my analysis,
#
# Using the chart above, it shows that there is a direct relationship between sales date and medications sold.
#
# Majority of patient bought medications more around january 2022 while majority of purchase was around the first week of a new month.

# %% [markdown]
# ## Time Series Forecasting sales of medications using FBProphet

# %%
# checking and visualizing the type of distribution of a feature column

def univariate_analysis(data, color, title1, title2):
    
    """
    Showing visualization of univariate
    analysis with displot and qqplot
    visualization from seaborn and statsmodel
    library.
    
    Parameters
    ----------
    data : DataFrame, array, or list of arrays, optional
        Dataset for plotting. If ``x`` and ``y`` are absent, this is
        interpreted as wide-form. Otherwise it is expected to be long-form. 
        
    title1: The title of the visualization, title1 for displot visualization
        And title2 for quantile plot from statsmodel.
        
    title2: The title of the visualization, title1 for displot visualization
        And title2 for quantile plot from statsmodel.
        
    Returns

fig : matplotlib figure
        
        Returns the Figure object with the plot drawn onto it.
    """
    
    fig, (ax1, ax2) = plt.subplots( # subplots
        
        ncols=2, # num of cols
        nrows=1, # num of rows
        
        figsize=(20, 6) # set the width and high
    )

    sns.distplot( # create a distplot visualization
        data, # data
        
        ax=ax1, # axes 1
        
        kde=True, # kde
        
        color=color # color
    )
    
    ax1.set(title=title1) # set the title 1
    
    qqplot( # qqplot (quantile plot)
            
        data, # data
        
        ax=ax2, # axes 2
        
        line='s' # line 
      
    )
    
    ax2.set(title=title2) # set the title 2
    
    return fig # returning the figure

# Sale quantity Data

univariate_analysis( # call the function
   
    data= med['sale_quantity'], # put the data
    
    color='red', # pick the color
    
    title1='Sale quantity Data Distribution', # title1
    
    title2='Quantile Plot' # title2
);

# sale rate Data

univariate_analysis( # call the function
    
    data = med ['sale_rate'], # put the data
    
    color='blue', # pick the color 
    
    title1='Sale rate of medication Data Distribution', # title1 
   
    title2='Quantile Plot' # title2
);

# Sale date Data

univariate_analysis( # call the function

    data = med['sales_date'], # put the data
    
    color='green', # pick the color
    
    title1='Sale date of medication Data Distribution', # title1 
    
    title2='Quantile Plot' # title2
);



# Net amt Data

univariate_analysis( # call the function
    
    data = med['net_amt'], # put the data 
    
    color='black', # pick the color
    
    title1='Total net amount data Distribution', # title1 
    
    title2='Quantile Plot' # title2
);
# Out:
# C:\Users\pharmacy1\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#
# C:\Users\pharmacy1\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#
# C:\Users\pharmacy1\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# ...

# %%
data_for_outlier_ts = med.groupby(['medications'])['net_amt'].sum().reset_index()

data_for_outlier_ts.shape
# Out:
# (664, 2)

# %%
data_for_outlier_ts
# Out:
#                                medications   net_amt
# 0               10% BENZOYL PEROXIDE CREAM   14000.0
# 1                 5% BENZOYL PEROXIDE WASH    6000.0
# 2                  ABIDEC BABY DROPS 25 ML   42000.0
# 3    ABSORBED TETANUS VACCINE 0.5 ML (SII)   91125.0
# 4        ABSORBENT COTTON WOOL 450GRM (LP)    2000.0
# ..                                     ...       ...
# 659          ZITHROMAX AZYTHROMYCIN 250 MG  274150.0
# 660         ZITHROMAX SUSPENSION 200MG/5ML  136530.0
# 661                ZOLAT ALBENDAZOLE SYRUP    9550.0
# 662          ZYNCET - CETIRIZINE 10MG TABS   19231.5
# 663  ZYNCET - CETRIZINE SYRUP 5MG/5ML 60ML   52090.4
#
# [664 rows x 2 columns]

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

ts=data_for_outlier_ts.groupby(["medications"])["net_amt"].sum()

ts.astype('float')

plt.figure(figsize=(16,8))

plt.title('Total Revenue')

plt.xlabel('medications')

plt.ylabel('net amount')

plt.plot(ts);

# %%
plt.figure(figsize=(16,6))

plt.plot(ts.rolling(window=12,center=False).mean(),label='Rolling Mean');

plt.plot(ts.rolling(window=12,center=False).std(),label='Rolling sd');

plt.legend();

# %%
data_for_outlier_plot = med.set_index("sales_date")

data_for_outlier_plot.index = pd.to_datetime(data_for_outlier_plot.index)

data_for_outlier_plot = data_for_outlier_plot[['net_amt']].resample('M').mean()

data_for_outlier_plot.head()
# Out:
#                 net_amt
# sales_date
# 2022-01-31  3309.071810
# 2022-02-28  2995.061528
# 2022-03-31  2496.142634
# 2022-04-30  2841.868238
# 2022-05-31  2993.016927

# %%
trace3 = go.Scatter(
    
    x = data_for_outlier_plot.index,
    
    y = data_for_outlier_plot.net_amt
)

layout3 = go.Layout(

    title = "Average sales by Month",
    
    xaxis = dict(title = 'Month'),
    
    yaxis = dict(title = 'Price')
)

data3 = [trace3]

figure3 = go.Figure(data = data3, layout = layout3)

py.iplot(figure3)
# Out:
#         <iframe
#             width="100%"
#             height="525px"
#             src="https://plotly.com/~masrinez/9.embed"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# **From the visualization above, I observed our sales of medications at the hospital is likely to drop around the period of September 2022 to December 2022 which we expect an Immediate increase in the sales of medications from December 2022 to January 2023**

# %% [markdown]
# # Conclusions

# %% [markdown]
# So during my analysis of this dataset, I was able to come up with the following findings:
#
# 1) Pharmaceutical medical representative covering the Island territory of Lagos to target those commonly sold products to various private and government hospitals and healthcare facilities
#
# 2) Sales of medications is dependent on the month of the year due to various factors affecting each month.

# %%
from subprocess import call

call(['python', '-m', 'nbconvert', 'Investigate_a_Dataset.ipynb'])
# Out:
# 4294967295
